# %%
import pymongo

# %%
# To establish the Connection
from pymongo import MongoClient
client = MongoClient('localhost',27017)

# %%
# Rapid Api Covid Data
import http.client

conn = http.client.HTTPSConnection("covid-193.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "53b3a2e926msh2462cda27656d3ap1dfe19jsn49a21ee3365f",
    'x-rapidapi-host': "covid-193.p.rapidapi.com"
}

conn.request("GET", "/statistics", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"get":"statistics","parameters":[],"errors":[],"results":238,"response":[{"continent":"Africa","country":"Saint-Helena","population":6115,"cases":{"new":null,"active":2164,"critical":null,"recovered":2,"1M_pop":"354211","total":2166},"deaths":{"new":null,"1M_pop":null,"total":null},"tests":{"1M_pop":null,"total":null},"day":"2024-09-04","time":"2024-09-04T05:15:21+00:00"},{"continent":"South-America","country":"Falkland-Islands","population":3539,"cases":{"new":null,"active":0,"critical":null,"recovered":1930,"1M_pop":"545352","total":1930},"deaths":{"new":null,"1M_pop":null,"total":null},"tests":{"1M_pop":"2439107","total":8632},"day":"2024-09-04","time":"2024-09-04T05:15:21+00:00"},{"continent":"North-America","country":"Montserrat","population":4965,"cases":{"new":null,"active":19,"critical":null,"recovered":1376,"1M_pop":"282578","total":1403},"deaths":{"new":null,"1M_pop":"1611","total":8},"tests":{"1M_pop":"3577442","total":17762},"day":"2024-09-04","time":"2024-09-04T05:15:21
# ...

# %%
# Our data is in response key
null=""
data = eval(data)["response"]

# %%
data
# Out:
# [{'continent': 'Africa',
#   'country': 'Saint-Helena',
#   'population': 6115,
#   'cases': {'new': '',
#    'active': 2164,
#    'critical': '',
#    'recovered': 2,
#    '1M_pop': '354211',
#    'total': 2166},
#   'deaths': {'new': '', '1M_pop': '', 'total': ''},
#   'tests': {'1M_pop': '', 'total': ''},
#   'day': '2024-09-04',
#   'time': '2024-09-04T05:15:21+00:00'},
#  {'continent': 'South-America',
#   'country': 'Falkland-Islands',
#   'population': 3539,
#   'cases': {'new': '',
#    'active': 0,
#    'critical': '',
#    'recovered': 1930,
#    '1M_pop': '545352',
#    'total': 1930},
#   'deaths': {'new': '', '1M_pop': '', 'total': ''},
#   'tests': {'1M_pop': '2439107', 'total': 8632},
#   'day': '2024-09-04',
#   'time': '2024-09-04T05:15:21+00:00'},
#  {'continent': 'North-America',
#   'country': 'Montserrat',
#   'population': 4965,
#   'cases': {'new': '',
#    'active': 19,
#    'critical': '',
#    'recovered': 1376,
#    '1M_pop': '282578',
#    'total': 1403},
# ...

# %%
# Creating a database in Mongo Db
database = client.get_database(name="Covid")

# %%
database.CovidDate.insert_many(data)
# Out:
# InsertManyResult([ObjectId('66d7efd44fb112c691af0a46'), ObjectId('66d7efd44fb112c691af0a47'), ObjectId('66d7efd44fb112c691af0a48'), ObjectId('66d7efd44fb112c691af0a49'), ObjectId('66d7efd44fb112c691af0a4a'), ObjectId('66d7efd44fb112c691af0a4b'), ObjectId('66d7efd44fb112c691af0a4c'), ObjectId('66d7efd44fb112c691af0a4d'), ObjectId('66d7efd44fb112c691af0a4e'), ObjectId('66d7efd44fb112c691af0a4f'), ObjectId('66d7efd44fb112c691af0a50'), ObjectId('66d7efd44fb112c691af0a51'), ObjectId('66d7efd44fb112c691af0a52'), ObjectId('66d7efd44fb112c691af0a53'), ObjectId('66d7efd44fb112c691af0a54'), ObjectId('66d7efd44fb112c691af0a55'), ObjectId('66d7efd44fb112c691af0a56'), ObjectId('66d7efd44fb112c691af0a57'), ObjectId('66d7efd44fb112c691af0a58'), ObjectId('66d7efd44fb112c691af0a59'), ObjectId('66d7efd44fb112c691af0a5a'), ObjectId('66d7efd44fb112c691af0a5b'), ObjectId('66d7efd44fb112c691af0a5c'), ObjectId('66d7efd44fb112c691af0a5d'), ObjectId('66d7efd44fb112c691af0a5e'), ObjectId('66d7efd44fb112c691af
# ...
